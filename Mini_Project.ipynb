# %%
import pandas as pd

# %%
#Data Exploration
ds = pd.read_csv('Delivery_Tracking_Data.csv', encoding = 'ISO-8859-1')

# %%
df = pd.DataFrame(ds)
df
# Out:
#       Order_ID     Customer_Name  Delivery_Time              Route  \
# 0         1001        Nitya Gera              7      Delhi-Kolkata
# 1         1002       Akarsh Kibe              7  Bangalore-Chennai
# 2         1003      Ayesha Desai              9  Chennai-Hyderabad
# 3         1004       Krish Andra              5  Hyderabad-Chennai
# 4         1005      Tanya Talwar              4  Hyderabad-Chennai
# ...        ...               ...            ...                ...
# 4995      5996     Ehsaan Mander             13    Kolkata-Chennai
# 4996      5997      Darshit Kata             13  Chennai-Hyderabad
# 4997      5998    Drishya Luthra              2  Bangalore-Chennai
# 4998      5999  Dhanuk Ramaswamy              7  Chennai-Hyderabad
# 4999      6000      Taimur Dalal              3  Hyderabad-Chennai
#
#       Distance_km       Order_Date    Delivery_Date Delivery_Status  \
# 0            1086   11/4/2023 0:00  11/11/2023 0:00         On Time
# ...

# %%
#Display the first 5 and last 5 rows of the dataset.
df.head(5)
# Out:
#    Order_ID Customer_Name  Delivery_Time              Route  Distance_km  \
# 0      1001    Nitya Gera              7      Delhi-Kolkata         1086
# 1      1002   Akarsh Kibe              7  Bangalore-Chennai          833
# 2      1003  Ayesha Desai              9  Chennai-Hyderabad         1238
# 3      1004   Krish Andra              5  Hyderabad-Chennai         1793
# 4      1005  Tanya Talwar              4  Hyderabad-Chennai          358
#
#        Order_Date    Delivery_Date Delivery_Status Delay_Reason   Price
# 0  11/4/2023 0:00  11/11/2023 0:00         On Time          NaN  1554.0
# 1  7/26/2023 0:00    8/2/2023 0:00         On Time          NaN  2349.0
# 2  8/22/2023 0:00   8/31/2023 0:00         On Time          NaN  1039.0
# 3  1/24/2023 0:00   1/29/2023 0:00           Early          NaN  1148.0
# 4  1/26/2023 0:00   1/30/2023 0:00         Delayed      Weather  2464.0

# %%
df.tail(5)
# Out:
#       Order_ID     Customer_Name  Delivery_Time              Route  \
# 4995      5996     Ehsaan Mander             13    Kolkata-Chennai
# 4996      5997      Darshit Kata             13  Chennai-Hyderabad
# 4997      5998    Drishya Luthra              2  Bangalore-Chennai
# 4998      5999  Dhanuk Ramaswamy              7  Chennai-Hyderabad
# 4999      6000      Taimur Dalal              3  Hyderabad-Chennai
#
#       Distance_km       Order_Date    Delivery_Date Delivery_Status  \
# 4995          863  12/12/2023 0:00  12/25/2023 0:00         Delayed
# 4996         1480  12/31/2023 0:00   1/13/2024 0:00         On Time
# 4997         1234  12/16/2023 0:00  12/18/2023 0:00         On Time
# 4998          791   12/2/2023 0:00   12/9/2023 0:00         On Time
# 4999         1823    4/4/2023 0:00    4/7/2023 0:00         On Time
#
#      Delay_Reason   Price
# 4995  Route Issue  1851.0
# 4996          NaN  1853.0
# 4997          NaN  2089.0
# 4998          NaN   926.0
# ...

# %%
#Check the shape of the dataset (rows and columns).
df.shape
# Out:
# (5000, 10)

# %%
#List the column names and data types of the dataset.
df.dtypes
# Out:
# Order_ID             int64
# Customer_Name       object
# Delivery_Time        int64
# Route               object
# Distance_km          int64
# Order_Date          object
# Delivery_Date       object
# Delivery_Status     object
# Delay_Reason        object
# Price              float64
# dtype: object

# %%
#Check for missing values in the dataset and count them.
df.isnull().sum()
# Out:
# Order_ID              0
# Customer_Name         5
# Delivery_Time         0
# Route                 4
# Distance_km           0
# Order_Date            0
# Delivery_Date         0
# Delivery_Status       0
# Delay_Reason       3521
# Price                 6
# dtype: int64

# %%
filled_data = df.fillna(0)

# %%
filled_data
# Out:
#       Order_ID     Customer_Name  Delivery_Time              Route  \
# 0         1001        Nitya Gera              7      Delhi-Kolkata
# 1         1002       Akarsh Kibe              7  Bangalore-Chennai
# 2         1003      Ayesha Desai              9  Chennai-Hyderabad
# 3         1004       Krish Andra              5  Hyderabad-Chennai
# 4         1005      Tanya Talwar              4  Hyderabad-Chennai
# ...        ...               ...            ...                ...
# 4995      5996     Ehsaan Mander             13    Kolkata-Chennai
# 4996      5997      Darshit Kata             13  Chennai-Hyderabad
# 4997      5998    Drishya Luthra              2  Bangalore-Chennai
# 4998      5999  Dhanuk Ramaswamy              7  Chennai-Hyderabad
# 4999      6000      Taimur Dalal              3  Hyderabad-Chennai
#
#       Distance_km       Order_Date    Delivery_Date Delivery_Status  \
# 0            1086   11/4/2023 0:00  11/11/2023 0:00         On Time
# ...

# %%
filled_data.isnull().sum()
# Out:
# Order_ID           0
# Customer_Name      0
# Delivery_Time      0
# Route              0
# Distance_km        0
# Order_Date         0
# Delivery_Date      0
# Delivery_Status    0
# Delay_Reason       0
# Price              0
# dtype: int64

# %%
#Display summary statistics (mean, median, std, etc.) for the numerical columns.
df.describe()
# Out:
#           Order_ID  Delivery_Time  Distance_km        Price
# count  5000.000000    5000.000000  5000.000000  4994.000000
# mean   3500.500000       7.966600  1062.055200  1493.996796
# std    1443.520003       3.728789   543.384118   573.652253
# min    1001.000000       2.000000   100.000000   500.000000
# 25%    2250.750000       5.000000   602.000000   998.000000
# 50%    3500.500000       8.000000  1068.000000  1492.500000
# 75%    4750.250000      11.000000  1535.250000  1989.000000
# max    6000.000000      14.000000  1999.000000  2499.000000

# %%
#Identify any duplicate rows in the dataset and remove them.
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#incase to remove duplicated row use: drop_duplicates()

# %%
#Get the number of unique values in each column.
df.nunique()
# Out:
# Order_ID           5000
# Customer_Name      4871
# Delivery_Time        13
# Route                10
# Distance_km        1770
# Order_Date          365
# Delivery_Date       377
# Delivery_Status       3
# Delay_Reason          3
# Price              1844
# dtype: int64

# %%
#Data Cleaning
#Fill any missing values in numerical columns with the mean of the respective column.
df.isnull().sum()
# Out:
# Order_ID              0
# Customer_Name         5
# Delivery_Time         0
# Route                 4
# Distance_km           0
# Order_Date            0
# Delivery_Date         0
# Delivery_Status       0
# Delay_Reason       3521
# Price                 6
# dtype: int64

# %%
df['Price'] = df['Price'].fillna(df['Price'].mean())

# %%
df.isnull().sum()
# Out:
# Order_ID              0
# Customer_Name         5
# Delivery_Time         0
# Route                 4
# Distance_km           0
# Order_Date            0
# Delivery_Date         0
# Delivery_Status       0
# Delay_Reason       3521
# Price                 0
# dtype: int64

# %%
#Drop rows with any missing values.
df.dropna()
# Out:
#       Order_ID    Customer_Name  Delivery_Time              Route  \
# 4         1005     Tanya Talwar              4  Hyderabad-Chennai
# 7         1008       Piya Balay              3      Delhi-Kolkata
# 9         1010   Jayant Iyengar             11        Pune-Mumbai
# 14        1015      Riaan Kunda              7  Hyderabad-Chennai
# 21        1022      Vedika Dutt              9      Delhi-Kolkata
# ...        ...              ...            ...                ...
# 4977      5978      Stuvan Soni              5      Delhi-Kolkata
# 4980      5981  Hrishita Biswas             14  Chennai-Hyderabad
# 4986      5987      Gatik Ravel              8    Kolkata-Chennai
# 4988      5989      Ranbir Hans              3    Kolkata-Chennai
# 4995      5996    Ehsaan Mander             13    Kolkata-Chennai
#
#       Distance_km       Order_Date    Delivery_Date Delivery_Status  \
# 4             358   1/26/2023 0:00   1/30/2023 0:00         Delayed
# ...

# %%
#Replace all occurrences of a specific value in a column (e.g., replace 'NA' with NaN).
import numpy as np
df.replace('NaN', np.nan)
# Out:
#       Order_ID     Customer_Name  Delivery_Time              Route  \
# 0         1001        Nitya Gera              7      Delhi-Kolkata
# 1         1002       Akarsh Kibe              7  Bangalore-Chennai
# 2         1003      Ayesha Desai              9  Chennai-Hyderabad
# 3         1004       Krish Andra              5  Hyderabad-Chennai
# 4         1005      Tanya Talwar              4  Hyderabad-Chennai
# ...        ...               ...            ...                ...
# 4995      5996     Ehsaan Mander             13    Kolkata-Chennai
# 4996      5997      Darshit Kata             13  Chennai-Hyderabad
# 4997      5998    Drishya Luthra              2  Bangalore-Chennai
# 4998      5999  Dhanuk Ramaswamy              7  Chennai-Hyderabad
# 4999      6000      Taimur Dalal              3  Hyderabad-Chennai
#
#       Distance_km       Order_Date    Delivery_Date Delivery_Status  \
# 0            1086   11/4/2023 0:00  11/11/2023 0:00         On Time
# ...

# %%
#Remove a specific column from the dataset.
df.drop(columns = ['Delay_Reason'])
# Out:
#       Order_ID     Customer_Name  Delivery_Time              Route  \
# 0         1001        Nitya Gera              7      Delhi-Kolkata
# 1         1002       Akarsh Kibe              7  Bangalore-Chennai
# 2         1003      Ayesha Desai              9  Chennai-Hyderabad
# 3         1004       Krish Andra              5  Hyderabad-Chennai
# 4         1005      Tanya Talwar              4  Hyderabad-Chennai
# ...        ...               ...            ...                ...
# 4995      5996     Ehsaan Mander             13    Kolkata-Chennai
# 4996      5997      Darshit Kata             13  Chennai-Hyderabad
# 4997      5998    Drishya Luthra              2  Bangalore-Chennai
# 4998      5999  Dhanuk Ramaswamy              7  Chennai-Hyderabad
# 4999      6000      Taimur Dalal              3  Hyderabad-Chennai
#
#       Distance_km       Order_Date    Delivery_Date Delivery_Status   Price
# 0            1086   11/4/2023 0:00  11/11/2023 0:00         On Time  1554.0
# ...

# %%
#Rename a column from old_name to new_name.
df.rename(columns = {'Delay_Reason' : 'Reason'})
# Out:
#       Order_ID     Customer_Name  Delivery_Time              Route  \
# 0         1001        Nitya Gera              7      Delhi-Kolkata
# 1         1002       Akarsh Kibe              7  Bangalore-Chennai
# 2         1003      Ayesha Desai              9  Chennai-Hyderabad
# 3         1004       Krish Andra              5  Hyderabad-Chennai
# 4         1005      Tanya Talwar              4  Hyderabad-Chennai
# ...        ...               ...            ...                ...
# 4995      5996     Ehsaan Mander             13    Kolkata-Chennai
# 4996      5997      Darshit Kata             13  Chennai-Hyderabad
# 4997      5998    Drishya Luthra              2  Bangalore-Chennai
# 4998      5999  Dhanuk Ramaswamy              7  Chennai-Hyderabad
# 4999      6000      Taimur Dalal              3  Hyderabad-Chennai
#
#       Distance_km       Order_Date    Delivery_Date Delivery_Status  \
# 0            1086   11/4/2023 0:00  11/11/2023 0:00         On Time
# ...

# %%
df['Order_Date'] = pd.to_datetime(df['Order_Date'])

# %%
df
# Out:
#       Order_ID     Customer_Name  Delivery_Time              Route  \
# 0         1001        Nitya Gera              7      Delhi-Kolkata
# 1         1002       Akarsh Kibe              7  Bangalore-Chennai
# 2         1003      Ayesha Desai              9  Chennai-Hyderabad
# 3         1004       Krish Andra              5  Hyderabad-Chennai
# 4         1005      Tanya Talwar              4  Hyderabad-Chennai
# ...        ...               ...            ...                ...
# 4995      5996     Ehsaan Mander             13    Kolkata-Chennai
# 4996      5997      Darshit Kata             13  Chennai-Hyderabad
# 4997      5998    Drishya Luthra              2  Bangalore-Chennai
# 4998      5999  Dhanuk Ramaswamy              7  Chennai-Hyderabad
# 4999      6000      Taimur Dalal              3  Hyderabad-Chennai
#
#       Distance_km Order_Date    Delivery_Date Delivery_Status Delay_Reason  \
# 0            1086 2023-11-04  11/11/2023 0:00         On Time          NaN
# ...

# %%
df['Normalized__data'] = (df['Price'] - df['Price'].min()) / (df['Price'].max() - df['Price'].min()) 
df
# Out:
#       Order_ID     Customer_Name  Delivery_Time              Route  \
# 0         1001        Nitya Gera              7      Delhi-Kolkata
# 1         1002       Akarsh Kibe              7  Bangalore-Chennai
# 2         1003      Ayesha Desai              9  Chennai-Hyderabad
# 3         1004       Krish Andra              5  Hyderabad-Chennai
# 4         1005      Tanya Talwar              4  Hyderabad-Chennai
# ...        ...               ...            ...                ...
# 4995      5996     Ehsaan Mander             13    Kolkata-Chennai
# 4996      5997      Darshit Kata             13  Chennai-Hyderabad
# 4997      5998    Drishya Luthra              2  Bangalore-Chennai
# 4998      5999  Dhanuk Ramaswamy              7  Chennai-Hyderabad
# 4999      6000      Taimur Dalal              3  Hyderabad-Chennai
#
#       Distance_km Order_Date    Delivery_Date Delivery_Status Delay_Reason  \
# 0            1086 2023-11-04  11/11/2023 0:00         On Time          NaN
# ...

# %%
#Data Selection and Filtering
#Select the Price column from the DataFrame.
df['Price']
# Out:
# 0       1554.0
# 1       2349.0
# 2       1039.0
# 3       1148.0
# 4       2464.0
#          ...
# 4995    1851.0
# 4996    1853.0
# 4997    2089.0
# 4998     926.0
# 4999    1508.0
# Name: Price, Length: 5000, dtype: float64

# %%
#Select the Customer_Name and Price columns from the DataFrame.
df[['Customer_Name', 'Price']]
# Out:
#          Customer_Name   Price
# 0           Nitya Gera  1554.0
# 1          Akarsh Kibe  2349.0
# 2         Ayesha Desai  1039.0
# 3          Krish Andra  1148.0
# 4         Tanya Talwar  2464.0
# ...                ...     ...
# 4995     Ehsaan Mander  1851.0
# 4996      Darshit Kata  1853.0
# 4997    Drishya Luthra  2089.0
# 4998  Dhanuk Ramaswamy   926.0
# 4999      Taimur Dalal  1508.0
#
# [5000 rows x 2 columns]

# %%
#Filter the DataFrame to show rows where the Delivery_Time is greater than 7.
df[df['Delivery_Time']>7]
# Out:
#       Order_ID     Customer_Name  Delivery_Time              Route  \
# 2         1003      Ayesha Desai              9  Chennai-Hyderabad
# 9         1010    Jayant Iyengar             11        Pune-Mumbai
# 11        1012       Misha Dugal             12        Mumbai-Pune
# 12        1013        Mehul Brar             10        Pune-Mumbai
# 13        1014      Chirag Baria             12        Mumbai-Pune
# ...        ...               ...            ...                ...
# 4991      5992               NaN             11      Delhi-Kolkata
# 4993      5994     Tara Upadhyay             13      Delhi-Kolkata
# 4994      5995  Nayantara Khatri              8  Hyderabad-Chennai
# 4995      5996     Ehsaan Mander             13    Kolkata-Chennai
# 4996      5997      Darshit Kata             13  Chennai-Hyderabad
#
#       Distance_km Order_Date    Delivery_Date Delivery_Status Delay_Reason  \
# 2            1238 2023-08-22   8/31/2023 0:00         On Time          NaN
# ...

# %%
#Filter the dataset to display only rows where the Route is "Mumbai-Pune".
df[df['Route'] == 'Mumbai-Pune']
# Out:
#       Order_ID     Customer_Name  Delivery_Time        Route  Distance_km  \
# 11        1012       Misha Dugal             12  Mumbai-Pune         1964
# 13        1014      Chirag Baria             12  Mumbai-Pune          396
# 19        1020      Saanvi Ghosh              9  Mumbai-Pune          296
# 37        1038      Misha Kamdar              2  Mumbai-Pune         1218
# 38        1039      Raunak Barad              5  Mumbai-Pune          652
# ...        ...               ...            ...          ...          ...
# 4885      5886     Priyansh Dara              9  Mumbai-Pune          797
# 4900      5901       Alisha Dhar              3  Mumbai-Pune          804
# 4949      5950      Riaan Suresh              2  Mumbai-Pune         1435
# 4976      5977  Umang Srinivasan              2  Mumbai-Pune          989
# 4985      5986       Pranay Goda              4  Mumbai-Pune         1813
#
#      Order_Date    Delivery_Date Delivery_Status Delay_Reason   Price  \
# ...

# %%
#Sorting and Ordering
#Sort the DataFrame by Delivery_Time in ascending order.
df.sort_values(by = 'Delivery_Time')
# Out:
#       Order_ID     Customer_Name  Delivery_Time              Route  \
# 4323      5324      Zain Sachdev              2  Chennai-Hyderabad
# 4304      5305       Ojas Butala              2    Delhi-Hyderabad
# 833       1834      Saksham Saha              2        Mumbai-Pune
# 843       1844      Shayak Gupta              2    Delhi-Hyderabad
# 4293      5294       Fateh Walia              2    Kolkata-Chennai
# ...        ...               ...            ...                ...
# 1333      2334        Gokul Seth             14    Kolkata-Chennai
# 86        1087  Anahita Chandran             14  Bangalore-Chennai
# 4955      5956     Mohanlal Babu             14  Hyderabad-Chennai
# 4963      5964        Sana Bassi             14    Delhi-Hyderabad
# 4967      5968      Tejas Mannan             14   Mumbai-Bangalore
#
#       Distance_km Order_Date   Delivery_Date Delivery_Status Delay_Reason  \
# 4323         1122 2023-01-29  1/31/2023 0:00         On Time          NaN
# ...

# %%
#Sort the column alphabetically (for example, City).
df = df[sorted(df.columns)]
df
# Out:
#          Customer_Name Delay_Reason    Delivery_Date Delivery_Status  \
# 0           Nitya Gera          NaN  11/11/2023 0:00         On Time
# 1          Akarsh Kibe          NaN    8/2/2023 0:00         On Time
# 2         Ayesha Desai          NaN   8/31/2023 0:00         On Time
# 3          Krish Andra          NaN   1/29/2023 0:00           Early
# 4         Tanya Talwar      Weather   1/30/2023 0:00         Delayed
# ...                ...          ...              ...             ...
# 4995     Ehsaan Mander  Route Issue  12/25/2023 0:00         Delayed
# 4996      Darshit Kata          NaN   1/13/2024 0:00         On Time
# 4997    Drishya Luthra          NaN  12/18/2023 0:00         On Time
# 4998  Dhanuk Ramaswamy          NaN   12/9/2023 0:00         On Time
# 4999      Taimur Dalal          NaN    4/7/2023 0:00         On Time
#
#       Delivery_Time  Distance_km  Normalized__data Order_Date  Order_ID  \
# ...

# %%
#Sort the column in descending order (for example, Price).
df = df[sorted(df.columns, reverse = True)]
df
# Out:
#                   Route   Price  Order_ID Order_Date  Normalized__data  \
# 0         Delhi-Kolkata  1554.0      1001 2023-11-04          0.527264
# 1     Bangalore-Chennai  2349.0      1002 2023-07-26          0.924962
# 2     Chennai-Hyderabad  1039.0      1003 2023-08-22          0.269635
# 3     Hyderabad-Chennai  1148.0      1004 2023-01-24          0.324162
# 4     Hyderabad-Chennai  2464.0      1005 2023-01-26          0.982491
# ...                 ...     ...       ...        ...               ...
# 4995    Kolkata-Chennai  1851.0      5996 2023-12-12          0.675838
# 4996  Chennai-Hyderabad  1853.0      5997 2023-12-31          0.676838
# 4997  Bangalore-Chennai  2089.0      5998 2023-12-16          0.794897
# 4998  Chennai-Hyderabad   926.0      5999 2023-12-02          0.213107
# 4999  Hyderabad-Chennai  1508.0      6000 2023-04-04          0.504252
#
#       Distance_km  Delivery_Time Delivery_Status    Delivery_Date  \
# ...

# %%
#Sort the DataFrame by City first and then by Age.
df.sort_values(by=['Route', 'Customer_Name'], ascending = [True, False])
# Out:
#                   Route   Price  Order_ID Order_Date  Normalized__data  \
# 3691  Bangalore-Chennai  1459.0      4692 2023-07-14          0.479740
# 2738  Bangalore-Chennai  2228.0      3739 2023-07-04          0.864432
# 4030  Bangalore-Chennai   926.0      5031 2023-12-19          0.213107
# 4000  Bangalore-Chennai   911.0      5001 2023-02-04          0.205603
# 4717  Bangalore-Chennai  2191.0      5718 2023-02-09          0.845923
# ...                 ...     ...       ...        ...               ...
# 3317        Pune-Mumbai  1893.0      4318 2023-09-14          0.696848
# 4957                NaN  2377.0      5958 2023-06-20          0.938969
# 8                   NaN  1781.0      1009 2023-01-17          0.640820
# 4921                NaN  1731.0      5922 2023-07-30          0.615808
# 4990                NaN  2160.0      5991 2023-10-05          0.830415
#
#       Distance_km  Delivery_Time Delivery_Status    Delivery_Date  \
# ...

# %%
#Sort the DataFrame by Age and keep only the first 3 rows.
df.sort_values(by = 'Price').head(3)
# Out:
#                   Route  Price  Order_ID Order_Date  Normalized__data  \
# 3408       Delhi-Mumbai  500.0      4409 2023-08-19               0.0
# 1007  Hyderabad-Chennai  500.0      2008 2023-09-17               0.0
# 2665  Hyderabad-Chennai  500.0      3666 2023-07-02               0.0
#
#       Distance_km  Delivery_Time Delivery_Status   Delivery_Date Delay_Reason  \
# 3408         1719              7         On Time  8/26/2023 0:00          NaN
# 1007         1024             13         Delayed  9/30/2023 0:00  Route Issue
# 2665          348              4           Early   7/6/2023 0:00          NaN
#
#            Customer_Name
# 3408       Suhana Sarraf
# 1007         Nehmat Kari
# 2665  Manjari Ramanathan

# %%
#Renaming Columns
#Rename the City column to Location.
df.rename(columns = {'Route' : 'Location'})
# Out:
#                Location   Price  Order_ID Order_Date  Normalized__data  \
# 0         Delhi-Kolkata  1554.0      1001 2023-11-04          0.527264
# 1     Bangalore-Chennai  2349.0      1002 2023-07-26          0.924962
# 2     Chennai-Hyderabad  1039.0      1003 2023-08-22          0.269635
# 3     Hyderabad-Chennai  1148.0      1004 2023-01-24          0.324162
# 4     Hyderabad-Chennai  2464.0      1005 2023-01-26          0.982491
# ...                 ...     ...       ...        ...               ...
# 4995    Kolkata-Chennai  1851.0      5996 2023-12-12          0.675838
# 4996  Chennai-Hyderabad  1853.0      5997 2023-12-31          0.676838
# 4997  Bangalore-Chennai  2089.0      5998 2023-12-16          0.794897
# 4998  Chennai-Hyderabad   926.0      5999 2023-12-02          0.213107
# 4999  Hyderabad-Chennai  1508.0      6000 2023-04-04          0.504252
#
#       Distance_km  Delivery_Time Delivery_Status    Delivery_Date  \
# ...

# %%
#Rename the Age column to Person_Age.
df.rename(columns = {'Delivery_Status' : 'Status'})
# Out:
#                   Route   Price  Order_ID Order_Date  Normalized__data  \
# 0         Delhi-Kolkata  1554.0      1001 2023-11-04          0.527264
# 1     Bangalore-Chennai  2349.0      1002 2023-07-26          0.924962
# 2     Chennai-Hyderabad  1039.0      1003 2023-08-22          0.269635
# 3     Hyderabad-Chennai  1148.0      1004 2023-01-24          0.324162
# 4     Hyderabad-Chennai  2464.0      1005 2023-01-26          0.982491
# ...                 ...     ...       ...        ...               ...
# 4995    Kolkata-Chennai  1851.0      5996 2023-12-12          0.675838
# 4996  Chennai-Hyderabad  1853.0      5997 2023-12-31          0.676838
# 4997  Bangalore-Chennai  2089.0      5998 2023-12-16          0.794897
# 4998  Chennai-Hyderabad   926.0      5999 2023-12-02          0.213107
# 4999  Hyderabad-Chennai  1508.0      6000 2023-04-04          0.504252
#
#       Distance_km  Delivery_Time   Status    Delivery_Date Delay_Reason  \
# ...

# %%
#Rename multiple columns at once (e.g., Age to Age_Years and City to City_Name).
df.rename(columns = {'Delivery_Time' : 'Time', 'Delivery_Date': 'Expected_Date'})
# Out:
#                   Route   Price  Order_ID Order_Date  Normalized__data  \
# 0         Delhi-Kolkata  1554.0      1001 2023-11-04          0.527264
# 1     Bangalore-Chennai  2349.0      1002 2023-07-26          0.924962
# 2     Chennai-Hyderabad  1039.0      1003 2023-08-22          0.269635
# 3     Hyderabad-Chennai  1148.0      1004 2023-01-24          0.324162
# 4     Hyderabad-Chennai  2464.0      1005 2023-01-26          0.982491
# ...                 ...     ...       ...        ...               ...
# 4995    Kolkata-Chennai  1851.0      5996 2023-12-12          0.675838
# 4996  Chennai-Hyderabad  1853.0      5997 2023-12-31          0.676838
# 4997  Bangalore-Chennai  2089.0      5998 2023-12-16          0.794897
# 4998  Chennai-Hyderabad   926.0      5999 2023-12-02          0.213107
# 4999  Hyderabad-Chennai  1508.0      6000 2023-04-04          0.504252
#
#       Distance_km  Time Delivery_Status    Expected_Date Delay_Reason  \
# ...

# %%
#Change the column name to a simpler one (e.g., Product_Price to Price).
df.rename(columns = {'Customer_Name' : 'Name'})
# Out:
#                   Route   Price  Order_ID Order_Date  Normalized__data  \
# 0         Delhi-Kolkata  1554.0      1001 2023-11-04          0.527264
# 1     Bangalore-Chennai  2349.0      1002 2023-07-26          0.924962
# 2     Chennai-Hyderabad  1039.0      1003 2023-08-22          0.269635
# 3     Hyderabad-Chennai  1148.0      1004 2023-01-24          0.324162
# 4     Hyderabad-Chennai  2464.0      1005 2023-01-26          0.982491
# ...                 ...     ...       ...        ...               ...
# 4995    Kolkata-Chennai  1851.0      5996 2023-12-12          0.675838
# 4996  Chennai-Hyderabad  1853.0      5997 2023-12-31          0.676838
# 4997  Bangalore-Chennai  2089.0      5998 2023-12-16          0.794897
# 4998  Chennai-Hyderabad   926.0      5999 2023-12-02          0.213107
# 4999  Hyderabad-Chennai  1508.0      6000 2023-04-04          0.504252
#
#       Distance_km  Delivery_Time Delivery_Status    Delivery_Date  \
# ...

# %%
#Data Aggregation
#Find the average of the Age column.
df['Price'].mean()
# Out:
# np.float64(1493.9967961553864)

# %%
#Find the total sum of the Price column.
df['Price'].sum()
# Out:
# np.float64(7469983.980776932)

# %%
#Count how many times each value appears in the City column.
df['Route'].value_counts()
# Out:
# Route
# Chennai-Hyderabad    538
# Kolkata-Chennai      537
# Delhi-Mumbai         519
# Mumbai-Pune          515
# Pune-Mumbai          508
# Mumbai-Bangalore     507
# Delhi-Kolkata        485
# Bangalore-Chennai    483
# Hyderabad-Chennai    455
# Delhi-Hyderabad      449
# Name: count, dtype: int64

# %%
#Calculate the total sum of Age for each unique value in the City column.
df.groupby('Route')['Price'].sum()
# Out:
# Route
# Bangalore-Chennai    727298.996796
# Chennai-Hyderabad    798149.996796
# Delhi-Hyderabad      655107.996796
# Delhi-Kolkata        722413.996796
# Delhi-Mumbai         764593.000000
# Hyderabad-Chennai    681207.000000
# Kolkata-Chennai      824822.000000
# Mumbai-Bangalore     758492.993592
# Mumbai-Pune          778309.000000
# Pune-Mumbai          751540.000000
# Name: Price, dtype: float64

# %%
#Find the highest Age in the dataset.
df['Price'].max()
# Out:
# np.float64(2499.0)

# %%
#Calculate the minimum Price in the dataset.
df['Price'].min()
# Out:
# np.float64(500.0)

# %%
import matplotlib.pyplot as plt

# %%
#Simple Data Visualization
#Create a simple bar plot of City vs. Age.
# Calculate the average price for each route
route_price_avg = df.groupby('Route')['Price'].mean()

# Create a bar plot
route_price_avg.plot(kind='bar', color='skyblue')

# Add title and labels
plt.title('Average Price by Route')
plt.xlabel('Route')
plt.ylabel('Average Price')

# Show the plot
plt.show()

# %%
delay_counts = df['Delay_Reason'].value_counts()

# Create a line plot (plotting counts of each delay reason over index)
delay_counts.plot(kind='line', marker='o')

# Add title and labels
plt.title('Delay Reasons Over Index')
plt.xlabel('Delay Reason')
plt.ylabel('Frequency')
plt.show()

# %%
df['Delay_Reason'].value_counts().plot(kind='bar', color='lightgreen')

# Add title and labels
plt.title('Histogram of Delay Reasons')
plt.xlabel('Delay Reason')
plt.ylabel('Frequency')
plt.show()

# %%
df['Route'].value_counts().plot(kind='pie', autopct='%1.1f%%', colors=['#66b3ff', '#ff9999', '#c2c2f0', '#ffcc99'])

# Add title
plt.title('Distribution of Routes')
plt.ylabel('')  # Hides the y-label
plt.show()

# %%
df['Order_Date'] = pd.to_datetime(df['Order_Date'])
df['Delivery_Date'] = pd.to_datetime(df['Delivery_Date'])

# Create scatter plot
plt.scatter(df['Order_Date'], df['Delivery_Date'], color='orange')

# Add title and labels
plt.title('Scatter Plot: Order Date vs Delivery Date')
plt.xlabel('Order Date')
plt.ylabel('Delivery Date')
plt.show()

# %%
# Create box plot for 'Price' grouped by 'Route'
df.boxplot(column='Price', by='Route', patch_artist=True)

# Add title and labels
plt.title('Box Plot for Price by Route')
plt.suptitle('')
plt.xlabel('Route')
plt.ylabel('Price')
plt.show()

# %%
#Basic String Manipulation:
#Convert the City column values to lowercase.
df['Route'].str.lower()
# Out:
# 0           delhi-kolkata
# 1       bangalore-chennai
# 2       chennai-hyderabad
# 3       hyderabad-chennai
# 4       hyderabad-chennai
#               ...
# 4995      kolkata-chennai
# 4996    chennai-hyderabad
# 4997    bangalore-chennai
# 4998    chennai-hyderabad
# 4999    hyderabad-chennai
# Name: Route, Length: 5000, dtype: object

# %%
#Extract the first 3 characters of the City column.
df['Route'].str[:3]
# Out:
# 0       Del
# 1       Ban
# 2       Che
# 3       Hyd
# 4       Hyd
#        ...
# 4995    Kol
# 4996    Che
# 4997    Ban
# 4998    Che
# 4999    Hyd
# Name: Route, Length: 5000, dtype: object

# %%
df[['First_Name', 'Last_Name']] = df['Customer_Name'].str.split(' ', n =1 , expand = True)

# %%
df
# Out:
#                   Route   Price  Order_ID Order_Date  Normalized__data  \
# 0         Delhi-Kolkata  1554.0      1001 2023-11-04          0.527264
# 1     Bangalore-Chennai  2349.0      1002 2023-07-26          0.924962
# 2     Chennai-Hyderabad  1039.0      1003 2023-08-22          0.269635
# 3     Hyderabad-Chennai  1148.0      1004 2023-01-24          0.324162
# 4     Hyderabad-Chennai  2464.0      1005 2023-01-26          0.982491
# ...                 ...     ...       ...        ...               ...
# 4995    Kolkata-Chennai  1851.0      5996 2023-12-12          0.675838
# 4996  Chennai-Hyderabad  1853.0      5997 2023-12-31          0.676838
# 4997  Bangalore-Chennai  2089.0      5998 2023-12-16          0.794897
# 4998  Chennai-Hyderabad   926.0      5999 2023-12-02          0.213107
# 4999  Hyderabad-Chennai  1508.0      6000 2023-04-04          0.504252
#
#       Distance_km  Delivery_Time Delivery_Status Delivery_Date Delay_Reason  \
# ...

# %%
df = df.drop(columns='Customer_Name')

# %%
df
# Out:
#                   Route   Price  Order_ID Order_Date  Normalized__data  \
# 0         Delhi-Kolkata  1554.0      1001 2023-11-04          0.527264
# 1     Bangalore-Chennai  2349.0      1002 2023-07-26          0.924962
# 2     Chennai-Hyderabad  1039.0      1003 2023-08-22          0.269635
# 3     Hyderabad-Chennai  1148.0      1004 2023-01-24          0.324162
# 4     Hyderabad-Chennai  2464.0      1005 2023-01-26          0.982491
# ...                 ...     ...       ...        ...               ...
# 4995    Kolkata-Chennai  1851.0      5996 2023-12-12          0.675838
# 4996  Chennai-Hyderabad  1853.0      5997 2023-12-31          0.676838
# 4997  Bangalore-Chennai  2089.0      5998 2023-12-16          0.794897
# 4998  Chennai-Hyderabad   926.0      5999 2023-12-02          0.213107
# 4999  Hyderabad-Chennai  1508.0      6000 2023-04-04          0.504252
#
#       Distance_km  Delivery_Time Delivery_Status Delivery_Date Delay_Reason  \
# ...

# %%
#Concatenate the First_Name and Last_Name columns into a new column Full_Name.
df['Customer_Name'] = df['First_Name'] + ' ' + df['Last_Name']

# %%
df
# Out:
#                   Route   Price  Order_ID Order_Date  Normalized__data  \
# 0         Delhi-Kolkata  1554.0      1001 2023-11-04          0.527264
# 1     Bangalore-Chennai  2349.0      1002 2023-07-26          0.924962
# 2     Chennai-Hyderabad  1039.0      1003 2023-08-22          0.269635
# 3     Hyderabad-Chennai  1148.0      1004 2023-01-24          0.324162
# 4     Hyderabad-Chennai  2464.0      1005 2023-01-26          0.982491
# ...                 ...     ...       ...        ...               ...
# 4995    Kolkata-Chennai  1851.0      5996 2023-12-12          0.675838
# 4996  Chennai-Hyderabad  1853.0      5997 2023-12-31          0.676838
# 4997  Bangalore-Chennai  2089.0      5998 2023-12-16          0.794897
# 4998  Chennai-Hyderabad   926.0      5999 2023-12-02          0.213107
# 4999  Hyderabad-Chennai  1508.0      6000 2023-04-04          0.504252
#
#       Distance_km  Delivery_Time Delivery_Status Delivery_Date Delay_Reason  \
# ...

# %%
#Replace all spaces in the City column with underscores.
df['Route'].str.replace('-', ' to ')
# Out:
# 0           Delhi to Kolkata
# 1       Bangalore to Chennai
# 2       Chennai to Hyderabad
# 3       Hyderabad to Chennai
# 4       Hyderabad to Chennai
#                 ...
# 4995      Kolkata to Chennai
# 4996    Chennai to Hyderabad
# 4997    Bangalore to Chennai
# 4998    Chennai to Hyderabad
# 4999    Hyderabad to Chennai
# Name: Route, Length: 5000, dtype: object

# %%
#iloc - Integer-location based indexing:
#Select the first row of the dataset using iloc.
df.iloc[1]
# Out:
# Route                 Bangalore-Chennai
# Price                            2349.0
# Order_ID                           1002
# Order_Date          2023-07-26 00:00:00
# Normalized__data               0.924962
# Distance_km                         833
# Delivery_Time                         7
# Delivery_Status                 On Time
# Delivery_Date       2023-08-02 00:00:00
# Delay_Reason                        NaN
# First_Name                       Akarsh
# Last_Name                          Kibe
# Customer_Name               Akarsh Kibe
# Name: 1, dtype: object

# %%
#Select the last 3 rows of the dataset using iloc.
df.iloc[-3:]
# Out:
#                   Route   Price  Order_ID Order_Date  Normalized__data  \
# 4997  Bangalore-Chennai  2089.0      5998 2023-12-16          0.794897
# 4998  Chennai-Hyderabad   926.0      5999 2023-12-02          0.213107
# 4999  Hyderabad-Chennai  1508.0      6000 2023-04-04          0.504252
#
#       Distance_km  Delivery_Time Delivery_Status Delivery_Date Delay_Reason  \
# 4997         1234              2         On Time    2023-12-18          NaN
# 4998          791              7         On Time    2023-12-09          NaN
# 4999         1823              3         On Time    2023-04-07          NaN
#
#      First_Name  Last_Name     Customer_Name
# 4997    Drishya     Luthra    Drishya Luthra
# 4998     Dhanuk  Ramaswamy  Dhanuk Ramaswamy
# 4999     Taimur      Dalal      Taimur Dalal

# %%
#Select the first 5 rows and the first 3 columns using iloc.
df.iloc[:5,:3 ]
# Out:
#                Route   Price  Order_ID
# 0      Delhi-Kolkata  1554.0      1001
# 1  Bangalore-Chennai  2349.0      1002
# 2  Chennai-Hyderabad  1039.0      1003
# 3  Hyderabad-Chennai  1148.0      1004
# 4  Hyderabad-Chennai  2464.0      1005

# %%
#Select all rows of the dataset but only the 2nd and 3rd columns using iloc.
df.iloc[:,1:3]
# Out:
#        Price  Order_ID
# 0     1554.0      1001
# 1     2349.0      1002
# 2     1039.0      1003
# 3     1148.0      1004
# 4     2464.0      1005
# ...      ...       ...
# 4995  1851.0      5996
# 4996  1853.0      5997
# 4997  2089.0      5998
# 4998   926.0      5999
# 4999  1508.0      6000
#
# [5000 rows x 2 columns]

# %%
#Select the value at the 4th row and 2nd column using iloc.
df.iloc[3,1]
# Out:
# np.float64(1148.0)

# %%
#Use iloc to select rows 2 to 5 and columns 1 to 4.
df.iloc[1:5, :4]
# Out:
#                Route   Price  Order_ID Order_Date
# 1  Bangalore-Chennai  2349.0      1002 2023-07-26
# 2  Chennai-Hyderabad  1039.0      1003 2023-08-22
# 3  Hyderabad-Chennai  1148.0      1004 2023-01-24
# 4  Hyderabad-Chennai  2464.0      1005 2023-01-26

# %%
#loc - Label-based indexing
#Select the row where the Name is "Alice" using loc.
df.loc[df['Customer_Name'] == 'Krish Andra']
# Out:
#                Route   Price  Order_ID Order_Date  Normalized__data  \
# 3  Hyderabad-Chennai  1148.0      1004 2023-01-24          0.324162
#
#    Distance_km  Delivery_Time Delivery_Status Delivery_Date Delay_Reason  \
# 3         1793              5           Early    2023-01-29          NaN
#
#   First_Name Last_Name Customer_Name
# 3      Krish     Andra   Krish Andra

# %%
#Select rows where the Age is greater than 30 using loc.
df.loc[df['Delivery_Time']>10]
# Out:
#                   Route   Price  Order_ID Order_Date  Normalized__data  \
# 9           Pune-Mumbai  2041.0      1010 2023-09-02          0.770885
# 11          Mumbai-Pune  1933.0      1012 2023-09-15          0.716858
# 13          Mumbai-Pune  1274.0      1014 2023-07-24          0.387194
# 16        Delhi-Kolkata  1760.0      1017 2023-06-25          0.630315
# 18      Kolkata-Chennai  1891.0      1019 2023-09-05          0.695848
# ...                 ...     ...       ...        ...               ...
# 4989      Delhi-Kolkata  2301.0      5990 2023-07-28          0.900950
# 4991      Delhi-Kolkata  2406.0      5992 2023-07-25          0.953477
# 4993      Delhi-Kolkata  1123.0      5994 2023-11-24          0.311656
# 4995    Kolkata-Chennai  1851.0      5996 2023-12-12          0.675838
# 4996  Chennai-Hyderabad  1853.0      5997 2023-12-31          0.676838
#
#       Distance_km  Delivery_Time Delivery_Status Delivery_Date Delay_Reason  \
# ...

# %%
#Select the City column for rows where Age is between 20 and 40 using loc.
df.loc[(df['Delivery_Time']>= 10) & (df['Delivery_Time']<= 15)]
# Out:
#                   Route   Price  Order_ID Order_Date  Normalized__data  \
# 9           Pune-Mumbai  2041.0      1010 2023-09-02          0.770885
# 11          Mumbai-Pune  1933.0      1012 2023-09-15          0.716858
# 12          Pune-Mumbai   655.0      1013 2023-04-22          0.077539
# 13          Mumbai-Pune  1274.0      1014 2023-07-24          0.387194
# 16        Delhi-Kolkata  1760.0      1017 2023-06-25          0.630315
# ...                 ...     ...       ...        ...               ...
# 4989      Delhi-Kolkata  2301.0      5990 2023-07-28          0.900950
# 4991      Delhi-Kolkata  2406.0      5992 2023-07-25          0.953477
# 4993      Delhi-Kolkata  1123.0      5994 2023-11-24          0.311656
# 4995    Kolkata-Chennai  1851.0      5996 2023-12-12          0.675838
# 4996  Chennai-Hyderabad  1853.0      5997 2023-12-31          0.676838
#
#       Distance_km  Delivery_Time Delivery_Status Delivery_Date Delay_Reason  \
# ...

# %%
#Select all rows and columns where City is "New York" using loc.
df.loc[(df['Route'] == 'Delhi-Kolkata')]
# Out:
#               Route   Price  Order_ID Order_Date  Normalized__data  \
# 0     Delhi-Kolkata  1554.0      1001 2023-11-04          0.527264
# 6     Delhi-Kolkata   548.0      1007 2023-12-12          0.024012
# 7     Delhi-Kolkata  2402.0      1008 2023-01-10          0.951476
# 10    Delhi-Kolkata  1040.0      1011 2023-07-25          0.270135
# 16    Delhi-Kolkata  1760.0      1017 2023-06-25          0.630315
# ...             ...     ...       ...        ...               ...
# 4954  Delhi-Kolkata   985.0      5955 2023-12-09          0.242621
# 4977  Delhi-Kolkata  2084.0      5978 2023-02-02          0.792396
# 4989  Delhi-Kolkata  2301.0      5990 2023-07-28          0.900950
# 4991  Delhi-Kolkata  2406.0      5992 2023-07-25          0.953477
# 4993  Delhi-Kolkata  1123.0      5994 2023-11-24          0.311656
#
#       Distance_km  Delivery_Time Delivery_Status Delivery_Date Delay_Reason  \
# 0            1086              7         On Time    2023-11-11          NaN
# ...

# %%
#Select multiple columns (Name, City) for a specific row with loc.
df.loc[4, ['Customer_Name','Route']]
# Out:
# Customer_Name         Tanya Talwar
# Route            Hyderabad-Chennai
# Name: 4, dtype: object

# %%
#Use loc to select the row where Age is greater than 25 and the City is "Los Angeles".
df.loc[(df['Delivery_Time'] >= 10) & (df['Route'] =='Delhi-Kolkata')]
# Out:
#               Route   Price  Order_ID Order_Date  Normalized__data  \
# 16    Delhi-Kolkata  1760.0      1017 2023-06-25          0.630315
# 23    Delhi-Kolkata   526.0      1024 2023-08-28          0.013007
# 51    Delhi-Kolkata  1060.0      1052 2023-11-12          0.280140
# 99    Delhi-Kolkata  1072.0      1100 2023-07-08          0.286143
# 114   Delhi-Kolkata  1858.0      1115 2023-10-26          0.679340
# ...             ...     ...       ...        ...               ...
# 4937  Delhi-Kolkata   654.0      5938 2023-04-02          0.077039
# 4954  Delhi-Kolkata   985.0      5955 2023-12-09          0.242621
# 4989  Delhi-Kolkata  2301.0      5990 2023-07-28          0.900950
# 4991  Delhi-Kolkata  2406.0      5992 2023-07-25          0.953477
# 4993  Delhi-Kolkata  1123.0      5994 2023-11-24          0.311656
#
#       Distance_km  Delivery_Time Delivery_Status Delivery_Date Delay_Reason  \
# 16           1586             12         On Time    2023-07-07          NaN
# ...

# %%
#replace - Replacing values in a DataFrame
#Replace all occurrences of the value "New York" with "NYC" in the City column
df.replace('Mumbai-Pune', 'Bombay-Pune')
# Out:
#                   Route   Price  Order_ID Order_Date  Normalized__data  \
# 0         Delhi-Kolkata  1554.0      1001 2023-11-04          0.527264
# 1     Bangalore-Chennai  2349.0      1002 2023-07-26          0.924962
# 2     Chennai-Hyderabad  1039.0      1003 2023-08-22          0.269635
# 3     Hyderabad-Chennai  1148.0      1004 2023-01-24          0.324162
# 4     Hyderabad-Chennai  2464.0      1005 2023-01-26          0.982491
# ...                 ...     ...       ...        ...               ...
# 4995    Kolkata-Chennai  1851.0      5996 2023-12-12          0.675838
# 4996  Chennai-Hyderabad  1853.0      5997 2023-12-31          0.676838
# 4997  Bangalore-Chennai  2089.0      5998 2023-12-16          0.794897
# 4998  Chennai-Hyderabad   926.0      5999 2023-12-02          0.213107
# 4999  Hyderabad-Chennai  1508.0      6000 2023-04-04          0.504252
#
#       Distance_km  Delivery_Time Delivery_Status Delivery_Date Delay_Reason  \
# ...

# %%
#Replace the value 0 with NaN in a specific numerical column.
df.replace(0, np.nan)
# Out:
#                   Route   Price  Order_ID Order_Date  Normalized__data  \
# 0         Delhi-Kolkata  1554.0      1001 2023-11-04          0.527264
# 1     Bangalore-Chennai  2349.0      1002 2023-07-26          0.924962
# 2     Chennai-Hyderabad  1039.0      1003 2023-08-22          0.269635
# 3     Hyderabad-Chennai  1148.0      1004 2023-01-24          0.324162
# 4     Hyderabad-Chennai  2464.0      1005 2023-01-26          0.982491
# ...                 ...     ...       ...        ...               ...
# 4995    Kolkata-Chennai  1851.0      5996 2023-12-12          0.675838
# 4996  Chennai-Hyderabad  1853.0      5997 2023-12-31          0.676838
# 4997  Bangalore-Chennai  2089.0      5998 2023-12-16          0.794897
# 4998  Chennai-Hyderabad   926.0      5999 2023-12-02          0.213107
# 4999  Hyderabad-Chennai  1508.0      6000 2023-04-04          0.504252
#
#       Distance_km  Delivery_Time Delivery_Status Delivery_Date Delay_Reason  \
# ...

# %%
#Replace a value in the entire DataFrame (e.g., replace all 100s with 50s).
df.replace(1554.0, 1600, inplace = True)

# %%
df
# Out:
#       Order_ID     Customer_Name  Delivery_Time              Route  \
# 0         1001        Nitya Gera              7      Delhi-Kolkata
# 1         1002       Akarsh Kibe              7  Bangalore-Chennai
# 2         1003      Ayesha Desai              9  Chennai-Hyderabad
# 3         1004       Krish Andra              5  Hyderabad-Chennai
# 4         1005      Tanya Talwar              4  Hyderabad-Chennai
# ...        ...               ...            ...                ...
# 4995      5996     Ehsaan Mander             13    Kolkata-Chennai
# 4996      5997      Darshit Kata             13  Chennai-Hyderabad
# 4997      5998    Drishya Luthra              2  Bangalore-Chennai
# 4998      5999  Dhanuk Ramaswamy              7  Chennai-Hyderabad
# 4999      6000      Taimur Dalal              3  Hyderabad-Chennai
#
#       Distance_km       Order_Date    Delivery_Date Delivery_Status  \
# 0            1086   11/4/2023 0:00  11/11/2023 0:00         On Time
# ...

# %%
# Filter dataset where Distance_km is between 5 and 15 and Route is "Los Angeles"
filtered_df = df[(df["Distance_km"] >= 5) & (df["Distance_km"] <= 15) & (df["Route"] == "Los Angeles")]

# Group by Delivery_Status and calculate mean & median of Delivery_Time
aggregated_df = filtered_df.groupby("Delivery_Status")["Delivery_Time"].agg(["mean", "median"]).reset_index()

# Sort by mean Delivery_Time in descending order
aggregated_df = aggregated_df.sort_values(by="mean", ascending=False)

print(aggregated_df)
# Out:
# Empty DataFrame
# Columns: [Delivery_Status, mean, median]
# Index: []

# %%
# Ensure the column is of string type
df["Full_Name"] = df["Customer_Name"].astype(str)

# Handle cases where there may not be a last name (avoid NaN issues)
df[["First_Name", "Last_Name"]] = df["Full_Name"].str.split(n=1, expand=True).fillna("")

# Group by Route and count unique Full_Name entries
unique_customers = df.groupby("Route")["Full_Name"].nunique().reset_index()
unique_customers.rename(columns={"Full_Name": "Unique_Customers"}, inplace=True)

print(unique_customers)
# Out:
#                Route  Unique_Customers
# 0  Bangalore-Chennai               483
# 1  Chennai-Hyderabad               537
# 2    Delhi-Hyderabad               449
# 3      Delhi-Kolkata               482
# 4       Delhi-Mumbai               517
# 5  Hyderabad-Chennai               455
# 6    Kolkata-Chennai               537
# 7   Mumbai-Bangalore               507
# 8        Mumbai-Pune               512
# 9        Pune-Mumbai               506

# %%
# Normalize the Price column between 0 and 1 manually
df["Normalized_Price"] = (df["Price"] - df["Price"].min()) / (df["Price"].max() - df["Price"].min())

print(df[["Price", "Normalized_Price"]].head())  # Check the normalized values


# Replace negative Delivery_Time values with the median
median_delivery_time = df[df["Delivery_Time"] >= 0]["Delivery_Time"].median()
df["Delivery_Time"] = df["Delivery_Time"].apply(lambda x: median_delivery_time if x < 0 else x)

# Sample product_data DataFrame
product_data = pd.DataFrame({
    "Order_ID": df["Order_ID"].sample(10),  # Taking 10 random Order_IDs from df
    "Product_Name": ["Product_" + str(i) for i in range(10)],
    "Category": ["Category_" + str(i % 3) for i in range(10)]
})

# Merge with product_data on Order_ID
merged_df = pd.merge(df, product_data, on="Order_ID", how="left")

# Display first 5 rows of merged dataset
print(merged_df.head())
# Out:
#     Price  Normalized_Price
# 0  1554.0          0.527264
# 1  2349.0          0.924962
# 2  1039.0          0.269635
# 3  1148.0          0.324162
# 4  2464.0          0.982491
#    Order_ID Customer_Name  Delivery_Time              Route  Distance_km  \
# 0      1001    Nitya Gera              7      Delhi-Kolkata         1086
# 1      1002   Akarsh Kibe              7  Bangalore-Chennai          833
# 2      1003  Ayesha Desai              9  Chennai-Hyderabad         1238
# 3      1004   Krish Andra              5  Hyderabad-Chennai         1793
# 4      1005  Tanya Talwar              4  Hyderabad-Chennai          358
#
#        Order_Date    Delivery_Date Delivery_Status Delay_Reason   Price  \
# 0  11/4/2023 0:00  11/11/2023 0:00         On Time          NaN  1554.0
# 1  7/26/2023 0:00    8/2/2023 0:00         On Time          NaN  2349.0
# 2  8/22/2023 0:00   8/31/2023 0:00         On Time          NaN  1039.0
# ...
