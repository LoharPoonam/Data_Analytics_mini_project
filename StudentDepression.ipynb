# %%
import pandas as pd

# %%
ds = pd.read_csv("StudentDepressionDataset.csv")

# %%
ds
# Out:
#            id  Gender   Age           City Profession  Academic Pressure  \
# 0           2    Male  33.0  Visakhapatnam    Student                5.0
# 1           8  Female  24.0      Bangalore    Student                2.0
# 2          26    Male  31.0       Srinagar    Student                3.0
# 3          30  Female  28.0       Varanasi    Student                3.0
# 4          32  Female  25.0         Jaipur    Student                4.0
# ...       ...     ...   ...            ...        ...                ...
# 27896  140685  Female  27.0          Surat    Student                5.0
# 27897  140686    Male  27.0       Ludhiana    Student                2.0
# 27898  140689    Male  31.0      Faridabad    Student                3.0
# 27899  140690  Female  18.0       Ludhiana    Student                5.0
# 27900  140699    Male  27.0          Patna    Student                4.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# ...

# %%
ds.head()
# Out:
#    id  Gender   Age           City Profession  Academic Pressure  \
# 0   2    Male  33.0  Visakhapatnam    Student                5.0
# 1   8  Female  24.0      Bangalore    Student                2.0
# 2  26    Male  31.0       Srinagar    Student                3.0
# 3  30  Female  28.0       Varanasi    Student                3.0
# 4  32  Female  25.0         Jaipur    Student                4.0
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 0            0.0  8.97                 2.0               0.0
# 1            0.0  5.90                 5.0               0.0
# 2            0.0  7.03                 5.0               0.0
# 3            0.0  5.59                 2.0               0.0
# 4            0.0  8.13                 3.0               0.0
#
#       Sleep Duration Dietary Habits   Degree  \
# 0          5-6 hours        Healthy  B.Pharm
# 1          5-6 hours       Moderate      BSc
# 2  Less than 5 hours        Healthy       BA
# ...

# %%
ds.tail()
# Out:
#            id  Gender   Age       City Profession  Academic Pressure  \
# 27896  140685  Female  27.0      Surat    Student                5.0
# 27897  140686    Male  27.0   Ludhiana    Student                2.0
# 27898  140689    Male  31.0  Faridabad    Student                3.0
# 27899  140690  Female  18.0   Ludhiana    Student                5.0
# 27900  140699    Male  27.0      Patna    Student                4.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 27896            0.0  5.75                 5.0               0.0
# 27897            0.0  9.40                 3.0               0.0
# 27898            0.0  6.61                 4.0               0.0
# 27899            0.0  6.88                 2.0               0.0
# 27900            0.0  9.24                 1.0               0.0
#
#           Sleep Duration Dietary Habits    Degree  \
# 27896          5-6 hours      Unhealthy  Class 12
# 27897  Less than 5 hours        Healthy       MSc
# ...

# %%
ds.shape
# Out:
# (27901, 18)

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27901 entries, 0 to 27900
# Data columns (total 18 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     27901 non-null  int64
#  1   Gender                                 27901 non-null  object
#  2   Age                                    27901 non-null  float64
#  3   City                                   27901 non-null  object
#  4   Profession                             27901 non-null  object
#  5   Academic Pressure                      27901 non-null  float64
#  6   Work Pressure                          27901 non-null  float64
#  7   CGPA                                   27901 non-null  float64
#  8   Study Satisfaction                     27901 non-null  float64
#  9   Job Satisfaction                       27901 non-null  float64
# ...

# %%
ds.describe()
# Out:
#                   id           Age  Academic Pressure  Work Pressure  \
# count   27901.000000  27901.000000       27901.000000   27901.000000
# mean    70442.149421     25.822300           3.141214       0.000430
# std     40641.175216      4.905687           1.381465       0.043992
# min         2.000000     18.000000           0.000000       0.000000
# 25%     35039.000000     21.000000           2.000000       0.000000
# 50%     70684.000000     25.000000           3.000000       0.000000
# 75%    105818.000000     30.000000           4.000000       0.000000
# max    140699.000000     59.000000           5.000000       5.000000
#
#                CGPA  Study Satisfaction  Job Satisfaction  Work/Study Hours  \
# count  27901.000000        27901.000000      27901.000000      27901.000000
# mean       7.656104            2.943837          0.000681          7.156984
# std        1.470707            1.361148          0.044394          3.707642
# ...

# %%
ds['Age']
# Out:
# 0        33.0
# 1        24.0
# 2        31.0
# 3        28.0
# 4        25.0
#          ...
# 27896    27.0
# 27897    27.0
# 27898    31.0
# 27899    18.0
# 27900    27.0
# Name: Age, Length: 27901, dtype: float64

# %%
ds[['Age', 'Work Pressure']]
# Out:
#         Age  Work Pressure
# 0      33.0            0.0
# 1      24.0            0.0
# 2      31.0            0.0
# 3      28.0            0.0
# 4      25.0            0.0
# ...     ...            ...
# 27896  27.0            0.0
# 27897  27.0            0.0
# 27898  31.0            0.0
# 27899  18.0            0.0
# 27900  27.0            0.0
#
# [27901 rows x 2 columns]

# %%
ds.iloc[0]
# Out:
# id                                                   2
# Gender                                            Male
# Age                                               33.0
# City                                     Visakhapatnam
# Profession                                     Student
# Academic Pressure                                  5.0
# Work Pressure                                      0.0
# CGPA                                              8.97
# Study Satisfaction                                 2.0
# Job Satisfaction                                   0.0
# Sleep Duration                               5-6 hours
# Dietary Habits                                 Healthy
# Degree                                         B.Pharm
# Have you ever had suicidal thoughts ?              Yes
# Work/Study Hours                                   3.0
# Financial Stress                                   1.0
# Family History of Mental Illness                    No
# ...

# %%
ds.isnull()
# Out:
#           id  Gender    Age   City  Profession  Academic Pressure  \
# 0      False   False  False  False       False              False
# 1      False   False  False  False       False              False
# 2      False   False  False  False       False              False
# 3      False   False  False  False       False              False
# 4      False   False  False  False       False              False
# ...      ...     ...    ...    ...         ...                ...
# 27896  False   False  False  False       False              False
# 27897  False   False  False  False       False              False
# 27898  False   False  False  False       False              False
# 27899  False   False  False  False       False              False
# 27900  False   False  False  False       False              False
#
#        Work Pressure   CGPA  Study Satisfaction  Job Satisfaction  \
# 0              False  False               False             False
# ...

# %%
ds.isnull().sum()
# Out:
# id                                       0
# Gender                                   0
# Age                                      0
# City                                     0
# Profession                               0
# Academic Pressure                        0
# Work Pressure                            0
# CGPA                                     0
# Study Satisfaction                       0
# Job Satisfaction                         0
# Sleep Duration                           0
# Dietary Habits                           0
# Degree                                   0
# Have you ever had suicidal thoughts ?    0
# Work/Study Hours                         0
# Financial Stress                         3
# Family History of Mental Illness         0
# Depression                               0
# dtype: int64

# %%
ds.fillna(0)
# Out:
#            id  Gender   Age           City Profession  Academic Pressure  \
# 0           2    Male  33.0  Visakhapatnam    Student                5.0
# 1           8  Female  24.0      Bangalore    Student                2.0
# 2          26    Male  31.0       Srinagar    Student                3.0
# 3          30  Female  28.0       Varanasi    Student                3.0
# 4          32  Female  25.0         Jaipur    Student                4.0
# ...       ...     ...   ...            ...        ...                ...
# 27896  140685  Female  27.0          Surat    Student                5.0
# 27897  140686    Male  27.0       Ludhiana    Student                2.0
# 27898  140689    Male  31.0      Faridabad    Student                3.0
# 27899  140690  Female  18.0       Ludhiana    Student                5.0
# 27900  140699    Male  27.0          Patna    Student                4.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# ...

# %%
ds.sort_values(by='Age', ascending=False)
# Out:
#            id  Gender   Age       City Profession  Academic Pressure  \
# 9238    46602    Male  59.0     Nashik    Student                1.0
# 2909    14768  Female  58.0    Chennai    Student                4.0
# 14819   74887  Female  56.0   Ludhiana    Student                3.0
# 13499   68441    Male  54.0       Agra    Student                5.0
# 4386    22004  Female  51.0     Bhopal    Student                2.0
# ...       ...     ...   ...        ...        ...                ...
# 11349   57413    Male  18.0  Faridabad    Student                5.0
# 27823  140235    Male  18.0  Ahmedabad    Student                2.0
# 11355   57441    Male  18.0    Kolkata    Student                3.0
# 11356   57453    Male  18.0      Thane    Student                3.0
# 5431    27408  Female  18.0      Thane    Student                3.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 9238             0.0  8.14                 1.0               0.0
# ...

# %%
ds[ds['Have you ever had suicidal thoughts ?'] == 'Yes']
# Out:
#            id  Gender   Age           City Profession  Academic Pressure  \
# 0           2    Male  33.0  Visakhapatnam    Student                5.0
# 3          30  Female  28.0       Varanasi    Student                3.0
# 4          32  Female  25.0         Jaipur    Student                4.0
# 8          59    Male  28.0         Nagpur    Student                3.0
# 9          62    Male  31.0         Nashik    Student                2.0
# ...       ...     ...   ...            ...        ...                ...
# 27894  140681    Male  23.0       Srinagar    Student                3.0
# 27895  140684    Male  31.0        Lucknow    Student                2.0
# 27896  140685  Female  27.0          Surat    Student                5.0
# 27899  140690  Female  18.0       Ludhiana    Student                5.0
# 27900  140699    Male  27.0          Patna    Student                4.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# ...

# %%
ds
# Out:
#            id  Gender   Age           City Profession  Academic Pressure  \
# 0           2    Male  33.0  Visakhapatnam    Student                5.0
# 1           8  Female  24.0      Bangalore    Student                2.0
# 2          26    Male  31.0       Srinagar    Student                3.0
# 3          30  Female  28.0       Varanasi    Student                3.0
# 4          32  Female  25.0         Jaipur    Student                4.0
# ...       ...     ...   ...            ...        ...                ...
# 27896  140685  Female  27.0          Surat    Student                5.0
# 27897  140686    Male  27.0       Ludhiana    Student                2.0
# 27898  140689    Male  31.0      Faridabad    Student                3.0
# 27899  140690  Female  18.0       Ludhiana    Student                5.0
# 27900  140699    Male  27.0          Patna    Student                4.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# ...

# %%
ds = pd.read_csv("StudentDepressionDataset.csv")

# %%
ds['Have you ever had suicidal thoughts ?'] = ds['Have you ever had suicidal thoughts ?'].map({'Yes': 1, 'No': 0})
ds['Family History of Mental Illness'] = ds['Family History of Mental Illness'].map({'Yes': 1, 'No': 0})
print(ds[['Have you ever had suicidal thoughts ?', 'Family History of Mental Illness']])

# %%
ds
# Out:
#            id  Gender   Age           City Profession  Academic Pressure  \
# 0           2    Male  33.0  Visakhapatnam    Student                5.0
# 1           8  Female  24.0      Bangalore    Student                2.0
# 2          26    Male  31.0       Srinagar    Student                3.0
# 3          30  Female  28.0       Varanasi    Student                3.0
# 4          32  Female  25.0         Jaipur    Student                4.0
# ...       ...     ...   ...            ...        ...                ...
# 27896  140685  Female  27.0          Surat    Student                5.0
# 27897  140686    Male  27.0       Ludhiana    Student                2.0
# 27898  140689    Male  31.0      Faridabad    Student                3.0
# 27899  140690  Female  18.0       Ludhiana    Student                5.0
# 27900  140699    Male  27.0          Patna    Student                4.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# ...

# %%
ds['Have you ever had suicidal thoughts ?'] = ds['Have you ever had suicidal thoughts ?'].map({'Yes': 1, 'No': 0})
ds['Family History of Mental Illness'] = ds['Family History of Mental Illness'].map({'Yes': 1, 'No': 0})
print(ds[['Have you ever had suicidal thoughts ?', 'Family History of Mental Illness']])
# Out:
#        Have you ever had suicidal thoughts ?  Family History of Mental Illness
# 0                                          1                                 0
# 1                                          0                                 1
# 2                                          0                                 1
# 3                                          1                                 1
# 4                                          1                                 0
# ...                                      ...                               ...
# 27896                                      1                                 1
# 27897                                      0                                 1
# 27898                                      0                                 0
# 27899                                      1                                 0
# 27900                                      1                                 1
#
# ...

# %%
ds = pd.read_csv("StudentDepressionDataset.csv")
ds
# Out:
#            id  Gender   Age           City Profession  Academic Pressure  \
# 0           2    Male  33.0  Visakhapatnam    Student                5.0
# 1           8  Female  24.0      Bangalore    Student                2.0
# 2          26    Male  31.0       Srinagar    Student                3.0
# 3          30  Female  28.0       Varanasi    Student                3.0
# 4          32  Female  25.0         Jaipur    Student                4.0
# ...       ...     ...   ...            ...        ...                ...
# 27896  140685  Female  27.0          Surat    Student                5.0
# 27897  140686    Male  27.0       Ludhiana    Student                2.0
# 27898  140689    Male  31.0      Faridabad    Student                3.0
# 27899  140690  Female  18.0       Ludhiana    Student                5.0
# 27900  140699    Male  27.0          Patna    Student                4.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# ...

# %%
ds.iloc[0, 1]
# Out:
# 'Male'

# %%
female_depressed = ds[(ds['Gender'] == 'Female') & (ds['Depression'] == 1)]
print(female_depressed)
# Out:
#            id  Gender   Age       City Profession  Academic Pressure  \
# 3          30  Female  28.0   Varanasi    Student                3.0
# 14        103  Female  19.0     Kalyan    Student                5.0
# 17        132  Female  20.0  Ahmedabad    Student                5.0
# 22        166  Female  25.0  Ahmedabad    Student                3.0
# 25        176  Female  20.0     Mumbai    Student                5.0
# ...       ...     ...   ...        ...        ...                ...
# 27875  140531  Female  23.0  Faridabad    Student                3.0
# 27883  140584  Female  22.0     Kanpur    Student                4.0
# 27886  140601  Female  22.0     Jaipur    Student                5.0
# 27891  140645  Female  28.0      Thane    Student                4.0
# 27899  140690  Female  18.0   Ludhiana    Student                5.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 3                0.0  5.59                 2.0               0.0
# ...

# %%
unique_cities = ds['City'].nunique()
print(f"Unique cities: {unique_cities}")
# Out:
# Unique cities: 52

# %%
unique_cities = ds['City'].unique()
print(unique_cities)
# Out:
# ['Visakhapatnam' 'Bangalore' 'Srinagar' 'Varanasi' 'Jaipur' 'Pune' 'Thane'
#  'Chennai' 'Nagpur' 'Nashik' 'Vadodara' 'Kalyan' 'Rajkot' 'Ahmedabad'
#  'Kolkata' 'Mumbai' 'Lucknow' 'Indore' 'Surat' 'Ludhiana' 'Bhopal'
#  'Meerut' 'Agra' 'Ghaziabad' 'Hyderabad' 'Vasai-Virar' 'Kanpur' 'Patna'
#  'Faridabad' 'Delhi' 'Saanvi' 'M.Tech' 'Bhavna' 'Less Delhi' 'City' '3.0'
#  'Less than 5 Kalyan' 'Mira' 'Harsha' 'Vaanya' 'Gaurav' 'Harsh' 'Reyansh'
#  'Kibara' 'Rashi' 'ME' 'M.Com' 'Nalyan' 'Mihir' 'Nalini' 'Nandini'
#  'Khaziabad']

# %%
average_cgpa = ds['CGPA'].mean()
print(f"Average CGPA: {average_cgpa}")
# Out:
# Average CGPA: 7.65610417189348

# %%
selected_data = ds.loc[:2, ['Age', 'CGPA']]
print(selected_data)
# Out:
#     Age  CGPA
# 0  33.0  8.97
# 1  24.0  5.90
# 2  31.0  7.03

# %%
ds = pd.read_csv("StudentDepressionDataset.csv")
ds
# Out:
#            id  Gender   Age           City Profession  Academic Pressure  \
# 0           2    Male  33.0  Visakhapatnam    Student                5.0
# 1           8  Female  24.0      Bangalore    Student                2.0
# 2          26    Male  31.0       Srinagar    Student                3.0
# 3          30  Female  28.0       Varanasi    Student                3.0
# 4          32  Female  25.0         Jaipur    Student                4.0
# ...       ...     ...   ...            ...        ...                ...
# 27896  140685  Female  27.0          Surat    Student                5.0
# 27897  140686    Male  27.0       Ludhiana    Student                2.0
# 27898  140689    Male  31.0      Faridabad    Student                3.0
# 27899  140690  Female  18.0       Ludhiana    Student                5.0
# 27900  140699    Male  27.0          Patna    Student                4.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# ...

# %%
ds[(ds['Gender'] == 'Female') & (ds['Depression'] == 1)]
# Out:
#            id  Gender   Age       City Profession  Academic Pressure  \
# 3          30  Female  28.0   Varanasi    Student                3.0
# 14        103  Female  19.0     Kalyan    Student                5.0
# 17        132  Female  20.0  Ahmedabad    Student                5.0
# 22        166  Female  25.0  Ahmedabad    Student                3.0
# 25        176  Female  20.0     Mumbai    Student                5.0
# ...       ...     ...   ...        ...        ...                ...
# 27875  140531  Female  23.0  Faridabad    Student                3.0
# 27883  140584  Female  22.0     Kanpur    Student                4.0
# 27886  140601  Female  22.0     Jaipur    Student                5.0
# 27891  140645  Female  28.0      Thane    Student                4.0
# 27899  140690  Female  18.0   Ludhiana    Student                5.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 3                0.0  5.59                 2.0               0.0
# ...

# %%
ds['City'].nunique()
# Out:
# 52

# %%
ds['City'].unique()
# Out:
# array(['Visakhapatnam', 'Bangalore', 'Srinagar', 'Varanasi', 'Jaipur',
#        'Pune', 'Thane', 'Chennai', 'Nagpur', 'Nashik', 'Vadodara',
#        'Kalyan', 'Rajkot', 'Ahmedabad', 'Kolkata', 'Mumbai', 'Lucknow',
#        'Indore', 'Surat', 'Ludhiana', 'Bhopal', 'Meerut', 'Agra',
#        'Ghaziabad', 'Hyderabad', 'Vasai-Virar', 'Kanpur', 'Patna',
#        'Faridabad', 'Delhi', 'Saanvi', 'M.Tech', 'Bhavna', 'Less Delhi',
#        'City', '3.0', 'Less than 5 Kalyan', 'Mira', 'Harsha', 'Vaanya',
#        'Gaurav', 'Harsh', 'Reyansh', 'Kibara', 'Rashi', 'ME', 'M.Com',
#        'Nalyan', 'Mihir', 'Nalini', 'Nandini', 'Khaziabad'], dtype=object)

# %%
ds['CGPA'].mean()
# Out:
# np.float64(7.65610417189348)

# %%
ds.loc[:2, ['Age', 'CGPA']]
# Out:
#     Age  CGPA
# 0  33.0  8.97
# 1  24.0  5.90
# 2  31.0  7.03

# %%
ds.loc[:2, ['Sleep Duration']]
# Out:
#       Sleep Duration
# 0          5-6 hours
# 1          5-6 hours
# 2  Less than 5 hours

# %%
ds.loc[ds['id'] == 2, 'Sleep Duration'] = "8-9 hours"
print(ds.loc[ds['id'] == 2])
# Out:
#    id Gender   Age           City Profession  Academic Pressure  \
# 0   2   Male  33.0  Visakhapatnam    Student                5.0
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction Sleep Duration  \
# 0            0.0  8.97                 2.0               0.0      8-9 hours
#
#   Dietary Habits   Degree Have you ever had suicidal thoughts ?  \
# 0        Healthy  B.Pharm                                   Yes
#
#    Work/Study Hours  Financial Stress Family History of Mental Illness  \
# 0               3.0               1.0                               No
#
#    Depression
# 0           1

# %%
if (ds['id'] == 0).any():
    ds.loc[ds['id'] == 0, 'Sleep Duration'] = "8-9 hours"
    print(ds.loc[ds['id'] == 0])
else:
    print("No row with id == 0 found.")
# Out:
# No row with id == 0 found.

# %%
ds = pd.read_csv("StudentDepressionDataset.csv")

# %%
ds.iloc[[0,1]]
# Out:
#    id  Gender   Age           City Profession  Academic Pressure  \
# 0   2    Male  33.0  Visakhapatnam    Student                5.0
# 1   8  Female  24.0      Bangalore    Student                2.0
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction Sleep Duration  \
# 0            0.0  8.97                 2.0               0.0      5-6 hours
# 1            0.0  5.90                 5.0               0.0      5-6 hours
#
#   Dietary Habits   Degree Have you ever had suicidal thoughts ?  \
# 0        Healthy  B.Pharm                                   Yes
# 1       Moderate      BSc                                    No
#
#    Work/Study Hours  Financial Stress Family History of Mental Illness  \
# 0               3.0               1.0                               No
# 1               3.0               2.0                              Yes
#
#    Depression
# 0           1
# 1           0

# %%
ds.iloc[[0,5],2]
# Out:
# 0    33.0
# 5    29.0
# Name: Age, dtype: float64

# %%
ds.loc[[0,5],['Profession','Degree']]
# Out:
#   Profession   Degree
# 0    Student  B.Pharm
# 5    Student      PhD

# %%
ds['City'].value_counts()
# Out:
# City
# Kalyan                1570
# Srinagar              1372
# Hyderabad             1340
# Vasai-Virar           1290
# Lucknow               1155
# Thane                 1139
# Ludhiana              1111
# Agra                  1094
# Surat                 1078
# Kolkata               1066
# Jaipur                1036
# Patna                 1007
# Visakhapatnam          969
# Pune                   968
# Ahmedabad              951
# Bhopal                 934
# Chennai                885
# Meerut                 825
# Rajkot                 816
# Delhi                  768
# Bangalore              767
# Ghaziabad              745
# Mumbai                 699
# Vadodara               694
# Varanasi               685
# Nagpur                 651
# Indore                 643
# Kanpur                 609
# Nashik                 547
# Faridabad              461
# Saanvi                   2
# Bhavna                   2
# City                     2
# Harsha                   2
# ...

# %%
ds.loc[[1,4,7],['Degree','Sleep Duration']]
# Out:
#      Degree     Sleep Duration
# 1       BSc          5-6 hours
# 4    M.Tech          5-6 hours
# 7  Class 12  Less than 5 hours

# %%
ds.loc[1:8,['Degree','Sleep Duration']]
# Out:
#      Degree     Sleep Duration
# 1       BSc          5-6 hours
# 2        BA  Less than 5 hours
# 3       BCA          7-8 hours
# 4    M.Tech          5-6 hours
# 5       PhD  Less than 5 hours
# 6       BSc          7-8 hours
# 7  Class 12  Less than 5 hours
# 8      B.Ed          7-8 hours

# %%
ds.loc[1:8:2,['Degree','Sleep Duration']]
# Out:
#      Degree     Sleep Duration
# 1       BSc          5-6 hours
# 3       BCA          7-8 hours
# 5       PhD  Less than 5 hours
# 7  Class 12  Less than 5 hours

# %%
ds.loc[1:8:2,'City':'Sleep Duration']
# Out:
#         City Profession  Academic Pressure  Work Pressure  CGPA  \
# 1  Bangalore    Student                2.0            0.0  5.90
# 3   Varanasi    Student                3.0            0.0  5.59
# 5       Pune    Student                2.0            0.0  5.70
# 7    Chennai    Student                2.0            0.0  8.04
#
#    Study Satisfaction  Job Satisfaction     Sleep Duration
# 1                 5.0               0.0          5-6 hours
# 3                 2.0               0.0          7-8 hours
# 5                 3.0               0.0  Less than 5 hours
# 7                 4.0               0.0  Less than 5 hours

# %%
ds.set_index('City')
# Out:
#                    id  Gender   Age Profession  Academic Pressure  \
# City
# Visakhapatnam       2    Male  33.0    Student                5.0
# Bangalore           8  Female  24.0    Student                2.0
# Srinagar           26    Male  31.0    Student                3.0
# Varanasi           30  Female  28.0    Student                3.0
# Jaipur             32  Female  25.0    Student                4.0
# ...               ...     ...   ...        ...                ...
# Surat          140685  Female  27.0    Student                5.0
# Ludhiana       140686    Male  27.0    Student                2.0
# Faridabad      140689    Male  31.0    Student                3.0
# Ludhiana       140690  Female  18.0    Student                5.0
# Patna          140699    Male  27.0    Student                4.0
#
#                Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# City
# Visakhapatnam            0.0  8.97                 2.0               0.0
# ...

# %%
ds.set_index('id', inplace=True)

# %%
# 32. Set 'id' as the index (in-place) and display the DataFrame
ds.set_index('id', inplace=True)
print(ds.head())  # Display the first few rows to verify the index change
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18928\3653086207.py in ?()
#       1 # 32. Set 'id' as the index (in-place) and display the DataFrame
# ----> 2 ds.set_index('id', inplace=True)
#       3 print(ds.head())  # Display the first few rows to verify the index change
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6118                     if not found:
#    6119                         missing.append(col)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#    6125             frame = self
#
# KeyError: "None of ['id'] are in the columns"

# %%
print(ds.columns)  # Display all column names
# Out:
# Index(['Gender', 'Age', 'City', 'Profession', 'Academic Pressure',
#        'Work Pressure', 'CGPA', 'Study Satisfaction', 'Job Satisfaction',
#        'Sleep Duration', 'Dietary Habits', 'Degree',
#        'Have you ever had suicidal thoughts ?', 'Work/Study Hours',
#        'Financial Stress', 'Family History of Mental Illness', 'Depression'],
#       dtype='object')

# %%
ds = pd.read_csv("StudentDepressionDataset.csv")

# %%
ds.set_index('id', inplace=True)
print(ds.head())
# Out:
#     Gender   Age           City Profession  Academic Pressure  Work Pressure  \
# id
# 2     Male  33.0  Visakhapatnam    Student                5.0            0.0
# 8   Female  24.0      Bangalore    Student                2.0            0.0
# 26    Male  31.0       Srinagar    Student                3.0            0.0
# 30  Female  28.0       Varanasi    Student                3.0            0.0
# 32  Female  25.0         Jaipur    Student                4.0            0.0
#
#     CGPA  Study Satisfaction  Job Satisfaction     Sleep Duration  \
# id
# 2   8.97                 2.0               0.0          5-6 hours
# 8   5.90                 5.0               0.0          5-6 hours
# 26  7.03                 5.0               0.0  Less than 5 hours
# 30  5.59                 2.0               0.0          7-8 hours
# 32  8.13                 3.0               0.0          5-6 hours
#
#    Dietary Habits   Degree Have you ever had suicidal thoughts ?  \
# id
# ...

# %%
ds = pd.read_csv("StudentDepressionDataset.csv")

# %%
ds.index
# Out:
# RangeIndex(start=0, stop=27901, step=1)

# %%
ds.loc[2]
# Out:
# id                                                      26
# Gender                                                Male
# Age                                                   31.0
# City                                              Srinagar
# Profession                                         Student
# Academic Pressure                                      3.0
# Work Pressure                                          0.0
# CGPA                                                  7.03
# Study Satisfaction                                     5.0
# Job Satisfaction                                       0.0
# Sleep Duration                           Less than 5 hours
# Dietary Habits                                     Healthy
# Degree                                                  BA
# Have you ever had suicidal thoughts ?                   No
# Work/Study Hours                                       9.0
# Financial Stress                                       1.0
# ...

# %%
ds.loc[[2],['Degree','City']]
# Out:
#   Degree      City
# 2     BA  Srinagar

# %%
ds.reset_index(inplace=True)

# %%
ds.head()
# Out:
#    index  id  Gender   Age           City Profession  Academic Pressure  \
# 0      0   2    Male  33.0  Visakhapatnam    Student                5.0
# 1      1   8  Female  24.0      Bangalore    Student                2.0
# 2      2  26    Male  31.0       Srinagar    Student                3.0
# 3      3  30  Female  28.0       Varanasi    Student                3.0
# 4      4  32  Female  25.0         Jaipur    Student                4.0
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 0            0.0  8.97                 2.0               0.0
# 1            0.0  5.90                 5.0               0.0
# 2            0.0  7.03                 5.0               0.0
# 3            0.0  5.59                 2.0               0.0
# 4            0.0  8.13                 3.0               0.0
#
#       Sleep Duration Dietary Habits   Degree  \
# 0          5-6 hours        Healthy  B.Pharm
# 1          5-6 hours       Moderate      BSc
# ...

# %%
ds.query('Gender == "Male"').head()
# Out:
#    index  id Gender   Age           City Profession  Academic Pressure  \
# 0      0   2   Male  33.0  Visakhapatnam    Student                5.0
# 2      2  26   Male  31.0       Srinagar    Student                3.0
# 5      5  33   Male  29.0           Pune    Student                2.0
# 6      6  52   Male  30.0          Thane    Student                3.0
# 8      8  59   Male  28.0         Nagpur    Student                3.0
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 0            0.0  8.97                 2.0               0.0
# 2            0.0  7.03                 5.0               0.0
# 5            0.0  5.70                 3.0               0.0
# 6            0.0  9.54                 4.0               0.0
# 8            0.0  9.79                 1.0               0.0
#
#       Sleep Duration Dietary Habits   Degree  \
# 0          5-6 hours        Healthy  B.Pharm
# 2  Less than 5 hours        Healthy       BA
# ...

# %%
ds.query('Gender == "Male"')[['Age','Degree']].head()
# Out:
#     Age   Degree
# 0  33.0  B.Pharm
# 2  31.0       BA
# 5  29.0      PhD
# 6  30.0      BSc
# 8  28.0     B.Ed

# %%
ds[(ds['City'] == "Kalyan") & (ds['Degree'] == "BCA")][['Financial Stress']].head()
# Out:
#       Financial Stress
# 568                5.0
# 656                3.0
# 778                2.0
# 1191               2.0
# 1375               5.0

# %%
ci_ty = ['Kalyan','Jaipur','Delhi']
filter = ds['City'].isin(ci_ty)
ds.loc[filter,'City']
# Out:
# 4        Jaipur
# 12       Kalyan
# 14       Kalyan
# 19       Kalyan
# 29       Kalyan
#           ...
# 27854    Kalyan
# 27860     Delhi
# 27872    Jaipur
# 27879    Kalyan
# 27886    Jaipur
# Name: City, Length: 3374, dtype: object

# %%
ds['Degree'].str.contains('MSc', na=False)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 27896    False
# 27897     True
# 27898    False
# 27899    False
# 27900    False
# Name: Degree, Length: 27901, dtype: bool
